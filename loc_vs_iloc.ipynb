# %%
import pandas as pd

# %%
df = pd.read_csv("vet_appointments.csv")

# %%
df.head()
# Out:
#        name species             breed  age     owner_name     visit_reason
# 0  Whiskers     Cat           Siamese    3       John Doe   Annual Checkup
# 1     Rusty     Dog  Golden Retriever    7     Jane Smith      Vaccination
# 2  Midnight     Cat   Black Shorthair    2  Alice Johnson    Ear Infection
# 3     Buddy     Dog          Labrador    6       John Doe    Hip Dysplasia
# 4    Fluffy     Cat           Persian    4  Michael Brown  Dental Cleaning

# %%
df.loc[0:9]
# Out:
#        name species             breed  age     owner_name     visit_reason
# 0  Whiskers     Cat           Siamese    3       John Doe   Annual Checkup
# 1     Rusty     Dog  Golden Retriever    7     Jane Smith      Vaccination
# 2  Midnight     Cat   Black Shorthair    2  Alice Johnson    Ear Infection
# 3     Buddy     Dog          Labrador    6       John Doe    Hip Dysplasia
# 4    Fluffy     Cat           Persian    4  Michael Brown  Dental Cleaning
# 5       Rex     Dog   German Shepherd    5   Robert White     Skin Allergy
# 6  Whiskers     Cat           Siamese    3       John Doe   Annual Checkup
# 7     Rusty     Dog  Golden Retriever    7     Jane Smith       Wound Care
# 8       Leo     Cat        Maine Coon    1  Alice Johnson      Vaccination
# 9   Charlie     Dog            Beagle    3  Michael Brown          Limping

# %%
df.iloc[0:9]
# Out:
#        name species             breed  age     owner_name     visit_reason
# 0  Whiskers     Cat           Siamese    3       John Doe   Annual Checkup
# 1     Rusty     Dog  Golden Retriever    7     Jane Smith      Vaccination
# 2  Midnight     Cat   Black Shorthair    2  Alice Johnson    Ear Infection
# 3     Buddy     Dog          Labrador    6       John Doe    Hip Dysplasia
# 4    Fluffy     Cat           Persian    4  Michael Brown  Dental Cleaning
# 5       Rex     Dog   German Shepherd    5   Robert White     Skin Allergy
# 6  Whiskers     Cat           Siamese    3       John Doe   Annual Checkup
# 7     Rusty     Dog  Golden Retriever    7     Jane Smith       Wound Care
# 8       Leo     Cat        Maine Coon    1  Alice Johnson      Vaccination

# %%
checkups = df.loc[df["visit_reason"] == "Annual Checkup"]

# %%
checkups.head()
# Out:
#         name species       breed  age     owner_name    visit_reason
# 0   Whiskers     Cat     Siamese    3       John Doe  Annual Checkup
# 6   Whiskers     Cat     Siamese    3       John Doe  Annual Checkup
# 11      Luna     Cat     Ragdoll    5     Jane Smith  Annual Checkup
# 17      Lucy     Dog      Poodle    2       John Doe  Annual Checkup
# 26       Leo     Cat  Maine Coon    1  Alice Johnson  Annual Checkup

# %%
checkups.loc[0:4]
# Out:
#        name species    breed  age owner_name    visit_reason
# 0  Whiskers     Cat  Siamese    3   John Doe  Annual Checkup

# %%
checkups.iloc[0:4]
# Out:
#         name species    breed  age  owner_name    visit_reason
# 0   Whiskers     Cat  Siamese    3    John Doe  Annual Checkup
# 6   Whiskers     Cat  Siamese    3    John Doe  Annual Checkup
# 11      Luna     Cat  Ragdoll    5  Jane Smith  Annual Checkup
# 17      Lucy     Dog   Poodle    2    John Doe  Annual Checkup

# %%
df2 = pd.read_csv("cats_countries.csv")

# %%
df2
# Out:
#       country_name  num_of_cats  cats_per_capita
# 0        Australia      4750000            0.200
# 1           Brazil      9800000            0.050
# 2           Canada      7350000            0.200
# 3            China     21000000            0.015
# 4          Denmark       590000            0.100
# 5            Egypt      7100000            0.080
# 6           France      9200000            0.140
# 7          Germany      8300000            0.100
# 8          Hungary      1150000            0.120
# 9            India     14800000            0.011
# 10           Japan      6800000            0.053
# 11           Kenya      2420000            0.050
# 12          Mexico      8200000            0.063
# 13           Nepal       880000            0.030
# 14            Oman       490000            0.100
# 15        Portugal      1290000            0.130
# 16           Qatar       390000            0.150
# 17          Russia     11200000            0.080
# ...

# %%
df2 = pd.read_csv("cats_countries.csv", index_col="country_name")

# %%
df2
# Out:
#                 num_of_cats  cats_per_capita
# country_name
# Australia           4750000            0.200
# Brazil              9800000            0.050
# Canada              7350000            0.200
# China              21000000            0.015
# Denmark              590000            0.100
# Egypt               7100000            0.080
# France              9200000            0.140
# Germany             8300000            0.100
# Hungary             1150000            0.120
# India              14800000            0.011
# Japan               6800000            0.053
# Kenya               2420000            0.050
# Mexico              8200000            0.063
# Nepal                880000            0.030
# Oman                 490000            0.100
# Portugal            1290000            0.130
# Qatar                390000            0.150
# Russia             11200000            0.080
# South Africa        3100000            0.055
# ...

# %%
df2.loc["Canada":"Oman", :]
# Out:
#               num_of_cats  cats_per_capita
# country_name
# Canada            7350000            0.200
# China            21000000            0.015
# Denmark            590000            0.100
# Egypt             7100000            0.080
# France            9200000            0.140
# Germany           8300000            0.100
# Hungary           1150000            0.120
# India            14800000            0.011
# Japan             6800000            0.053
# Kenya             2420000            0.050
# Mexico            8200000            0.063
# Nepal              880000            0.030
# Oman               490000            0.100

# %%
df2.iloc[0:4, :]
# Out:
#               num_of_cats  cats_per_capita
# country_name
# Australia         4750000            0.200
# Brazil            9800000            0.050
# Canada            7350000            0.200
# China            21000000            0.015
